# %% [markdown]
# ## **CNN:**
# rgb between 0 to 255 pixels......................
# to understanf the feature of neural network than we have to use convoutional

# %% [markdown]
# CNN helps to extract features from the given images  which is helpful in computer vision.
# and what is convoutional ?

# %% [markdown]
# when we slide the filter over the image we will get a new matrixx filter output.
# max pooling.

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from tensorflow import keras
from tensorflow.keras import layers,datasets,models

# %%
(train_images,train_labels),(test_images,test_labels)=datasets.cifar10.load_data()
# Out:
# ...
# 170508288/170498071 [==============================] - 2s 0us/step

# %%
train_images.shape
# Out:
# (50000, 32, 32, 3)

# %%
train_labels.shape
# Out:
# (50000, 1)

# %%
test_images.shape
# Out:
# (10000, 32, 32, 3)

# %%
train_labels.shape
# Out:
# (50000, 1)

# %%
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer','dog', 'frog', 'horse', 'ship', 'truck']

# %%
train_images[0]
# Out:
# array([[[ 59,  62,  63],
#         [ 43,  46,  45],
#         [ 50,  48,  43],
#         ...,
#         [158, 132, 108],
#         [152, 125, 102],
#         [148, 124, 103]],
#
#        [[ 16,  20,  20],
#         [  0,   0,   0],
#         [ 18,   8,   0],
#         ...,
#         [123,  88,  55],
#         [119,  83,  50],
#         [122,  87,  57]],
#
#        [[ 25,  24,  21],
#         [ 16,   7,   0],
#         [ 49,  27,   8],
#         ...,
#         [118,  84,  50],
#         [120,  84,  50],
#         [109,  73,  42]],
#
#        ...,
#
#        [[208, 170,  96],
#         [201, 153,  34],
#         [198, 161,  26],
#         ...,
#         [160, 133,  70],
#         [ 56,  31,   7],
#         [ 53,  34,  20]],
#
#        [[180, 139,  96],
#         [173, 123,  42],
#         [186, 144,  30],
#         ...,
#         [184, 148,  94],
#         [ 97,  62,  34],
#         [ 83,  53,  34]],
#
#        [[177, 144, 116],
#         [168, 129,  94],
#         [179, 142,  87],
# ...

# %%
train_labels[0][0]
# Out:
# 6

# %%
plt.figure(figsize=(10,10))
for i in range(25):
  plt.subplot(5,5,i+1)
  plt.imshow(test_images[i])
  plt.xlabel(train_labels[i][0])
  plt.show()

# %%
model=models.Sequential()

# %%
# model.add(layers.Conv2D(32,(3,3),activation='relu',input_shape(32,32,3))
# model.add(layers.MaxPool2D(pool_size=(2,2)))

# %%
model.add(layers.Conv2D(32,(3,3),activation='relu',input_shape=(32,32,3)))
model.add(layers.MaxPool2D(pool_size=(2,2)))

model.add(layers.Conv2D(64,(3,3),activation='relu'))
model.add(layers.MaxPool2D(pool_size=(2,2)))

model.add(layers.Conv2D(64,(3,3),activation='relu'))
model.add(layers.MaxPool2D(pool_size=(2,2)))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d (Conv2D)             (None, 30, 30, 32)        896
#
#  max_pooling2d (MaxPooling2D  (None, 15, 15, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 13, 13, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 6, 6, 64)         0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 4, 4, 64)          36928
#
#  max_pooling2d_2 (MaxPooling  (None, 2, 2, 64)         0
#  2D)
#
# ...
# Total params: 56,320
# Trainable params: 56,320
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# 1st convo provides 30 to 30 matrix *32

# %%
model.add(layers.Flatten())
model.add(layers.Dense(64,activation='relu'))
model.add(layers.Dense(10))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d (Conv2D)             (None, 30, 30, 32)        896
#
#  max_pooling2d (MaxPooling2D  (None, 15, 15, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 13, 13, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 6, 6, 64)         0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 4, 4, 64)          36928
#
#  max_pooling2d_2 (MaxPooling  (None, 2, 2, 64)         0
#  2D)
#
#  flatten (Flatten)           (None, 256)               0
#
#  dense (Dense)               (None, 64)                16448
#
#  dense_1 (Dense)             (None, 10)                650
#
# ...
# Total params: 73,418
# Trainable params: 73,418
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# In multi-class classification, accuracy is defined as follows:

# %%
model.compile(optimizer='adam',loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),metrics=['accuracy'])

# %%
history = model.fit(train_images, train_labels, epochs=10, 
                    validation_data=(test_images, test_labels))
# Out:
# Epoch 1/10
# 1563/1563 [==============================] - 77s 49ms/step - loss: 1.9628 - accuracy: 0.3652 - val_loss: 1.5403 - val_accuracy: 0.4357
# Epoch 2/10
#  537/1563 [=========>....................] - ETA: 43s - loss: 1.4699 - accuracy: 0.4664

# %%
plt.plot(history.history['accuracy'],label='accuracy')
plt.plot(history.history['val_accuracy'],label='validation accuracy')
plt.ylim([0.5,1])

# %%
test_loss,test_accuracy = model.evaluate(test_images,test_labels)

# %%
print(test_loss,test_accuracy)

# %% [markdown]
# [link text](https://)**how to interpret loss and accuracy of a model:**
#
# https://stackoverflow.com/questions/34518656/how-to-interpret-loss-and-accuracy-for-a-machine-learning-model
